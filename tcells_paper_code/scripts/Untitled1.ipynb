# %%
import numpy as np

covs_all = np.load('../data/simulation2/covs_all.npy')
cov = np.load('../data/simulation2/cov_pop.npy')

# %%
num_cells = 10
len_series = np.array([68, 116, 216, 216,  94, 216, 216, 190, 216, 216],dtype=np.int64)

# %%
ns0 = np.zeros((4,21),dtype=np.int64)
ns1 = np.zeros((4,34),dtype=np.int64)
ns2 = np.zeros((4,11),dtype=np.int64)

# %%
list0 = [0,3,4,6,7,9,10,11,12,13,15,18,19,20]
list1 = [2,3,7,8,9,12,14,15,16,17,18,20,24,25,26,28,31,32,33]
list2 = [2,4,5,6,7,8,9,10]

# %%
for i in range(4):
    for j in list0:
        #print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i,j+4],[i,j+4])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i,j+4],[i,j+4])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns0[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns0[i,j])
# Out:
# 0 0 2376
# 0 3 7919
# 0 4 0
# 0 6 83
# 0 7 15292
# 0 9 0
# 0 10 0
# 0 11 0
# 0 12 69
# 0 13 32
# 0 15 188
# 0 18 0
# 0 19 2146
# 0 20 23
# 1 0 28163
# 1 3 41319
# 1 4 0
# 1 6 0
# 1 7 7068
# 1 9 0
# 1 10 2862
# 1 11 0
# 1 12 0
# 1 13 0
# 1 15 0
# 1 18 0
# 1 19 204513
# 1 20 3176
# 2 0 2206486
# 2 3 419859
# 2 4 56613
# 2 6 32
# 2 7 47292
# 2 9 793
# 2 10 181088
# 2 11 11
# 2 12 313
# 2 13 1286
# 2 15 30
# 2 18 175
# 2 19 152161
# 2 20 4750
# 3 0 10389
# 3 3 12300
# 3 4 2
# 3 6 0
# 3 7 4162
# 3 9 5
# 3 10 0
# 3 11 1
# 3 12 0
# 3 13 314
# 3 15 0
# 3 18 0
# 3 19 2147
# 3 20 17

# %%
with open('../data/simulation2/ns0.npy','wb') as f:
    np.save(f, ns0)

# %%
ns0 = np.load('../data/simulation2/ns0.npy')

# %%
for i in range(4):
    for j in [0]:
        #print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i,j+4],[i,j+4])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i,j+4],[i,j+4])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns0[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns0[i,j])
# Out:
# 0 0 2340
# 1 0 27292
# 2 0 2175869
# 3 0 10189

# %%
with open('../data/simulation2/ns0.npy','wb') as f:
    np.save(f, ns0)

# %%
ns0 = np.load('../data/simulation2/ns0.npy')

# %%
for i in range(4):
    for j in [3,4,10,11,13]:
        #print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i,j+4],[i,j+4])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i,j+4],[i,j+4])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns0[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns0[i,j])
# Out:
# 0 3 7974
# 0 4 0
# 0 10 0
# 0 11 0
# 0 13 44
# 1 3 41861
# 1 4 0
# 1 10 2941
# 1 11 0
# 1 13 4
# 2 3 419474
# 2 4 56921
# 2 10 181184
# 2 11 6
# 2 13 1287
# 3 3 12221
# 3 4 1
# 3 10 0
# 3 11 0
# 3 13 393

# %%
with open('../data/simulation2/ns0.npy','wb') as f:
    np.save(f, ns0)

# %%
for i in range(4):
    for j in list1:
        print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i,j+25],[i,j+25])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i,j+25],[i,j+25])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns1[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns1[i,j])
# Out:
# 0 2
# 0 2 3208
# 0 7
# 0 7 22934
# 0 8
# 0 8 0
# 0 9
# 0 9 5227
# 0 12
# 0 12 4
# 0 14
# 0 14 143662
# 0 15
# 0 15 0
# 0 16
# 0 16 0
# 0 17
# 0 17 0
# 0 18
# 0 18 46328
# 0 20
# 0 20 5592
# 0 24
# 0 24 0
# 0 25
# 0 25 5999
# 0 26
# 0 26 3516
# 0 28
# 0 28 32
# 0 31
# 0 31 0
# 0 32
# 0 32 43868
# 0 33
# 0 33 101
# 1 2
# 1 2 0
# 1 7
# 1 7 1318605
# 1 8
# 1 8 0
# 1 9
# 1 9 3761
# 1 12
# 1 12 1
# 1 14
# 1 14 2398
# 1 15
# 1 15 0
# 1 16
# 1 16 0
# 1 17
# 1 17 0
# 1 18
# 1 18 1775
# 1 20
# 1 20 8533
# 1 24
# 1 24 3
# 1 25
# 1 25 33942
# 1 26
# 1 26 1377600
# 1 28
# 1 28 69
# 1 31
# 1 31 0
# 1 32
# 1 32 895
# 1 33
# 1 33 0
# 2 2
# 2 2 22147
# 2 7
# 2 7 1712405
# 2 8
# 2 8 14485
# 2 9
# 2 9 6009
# 2 12
# 2 12 348573
# 2 14
# 2 14 22996
# 2 15
# 2 15 526
# 2 16
# 2 16 152
# 2 17
# 2 17 19
# 2 18
# 2 18 2867
# 2 20
# 2 20 7637
# 2 24
# 2 24 11578
# 2 25
# 2 25 3454
# 2 26
# 2 26 632262
# 2 28
# 2 28 129859
# 2 31
# 2 31 111
# 2 32
# 2 32 2292
# 2 33
# 2 33 205
# 3 2
# 3 2 0
# 3 7
# 3 7 69833
# 3 8
# 3 8 38404
# 3 9
# 3 9 3954
# 3 12
# 3 12 7
# 3 14
# 3 14 2965
# 3 15
# 3 15 0
# 3 16
# 3 16 0
# 3 17
# 3 17 34
# 3 18
# 3 18 2064
# 3 20
# 3 20 71246
# 3 24
# 3 24 39593
# 3 25
# 3 25 3028
# 3 26
# 3 26 4462
# 3 28
# 3 28 3614
# 3 31
# 3 31 0
# 3 32
# 3 32 11911
# 3 33
# 3 33 416

# %%
with open('../data/simulation2/ns1.npy','wb') as f:
    np.save(f, ns1)

# %%
ns1 = np.load('../data/simulation2/ns1.npy')

# %%
for i in range(4):
    for j in [3]:
        print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i,j+25],[i,j+25])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i,j+25],[i,j+25])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns1[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns1[i,j])
# Out:
# 0 3
# 0 3 0
# 1 3
# 1 3 0
# 2 3
# 2 3 29995
# 3 3
# 3 3 2

# %%
with open('../data/simulation2/ns1.npy','wb') as f:
    np.save(f, ns1)

# %%
for i in range(4):
    for j in list2:
        print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i,j+59],[i,j+59])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i,j+59],[i,j+59])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns2[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns2[i,j])
# Out:
# 0 2
# 0 2 4459
# 0 4
# 0 4 1660
# 0 5
# 0 5 7260
# 0 6
# 0 6 0
# 0 7
# 0 7 57226
# 0 8
# 0 8 11
# 0 9
# 0 9 24
# 0 10
# 0 10 0
# 1 2
# 1 2 0
# 1 4
# 1 4 0
# 1 5
# 1 5 54
# 1 6
# 1 6 0
# 1 7
# 1 7 94
# 1 8
# 1 8 0
# 1 9
# 1 9 0
# 1 10
# 1 10 0
# 2 2
# 2 2 22167
# 2 4
# 2 4 38
# 2 5
# 2 5 25225
# 2 6
# 2 6 8647
# 2 7
# 2 7 239
# 2 8
# 2 8 22
# 2 9
# 2 9 3522
# 2 10
# 2 10 3542
# 3 2
# 3 2 0
# 3 4
# 3 4 0
# 3 5
# 3 5 1871
# 3 6
# 3 6 319
# 3 7
# 3 7 85
# 3 8
# 3 8 0
# 3 9
# 3 9 4
# 3 10
# 3 10 25

# %%
with open('../data/simulation2/ns2.npy','wb') as f:
    np.save(f, ns2)

# %%
import numpy as np

covs_all = np.load('../data/simulation2/covs_all.npy')
covs_all3 = np.load('../data/simulation2/covs_all3.npy')

# %%
print(covs_all[0,[7,10,11,13],19:25])
print(covs_all3[0,[7,10,11,13],19:25])
# Out:
# [[-5.24685926e-10  6.50628648e-11  2.98152477e-09 -3.96957564e-10
#   -1.82250889e-09 -1.30022455e-07]
#  [ 7.24560796e-10  7.09322179e-12 -4.55769416e-09  2.41843700e-10
#    1.01102464e-09  1.00421890e-07]
#  [-5.60454249e-13  2.54986180e-10  1.68791594e-09 -4.02841837e-11
#   -2.61805996e-10  1.94869091e-08]
#  [ 2.76574305e-10 -1.05239183e-10 -3.68145949e-09  2.95748753e-10
#    1.33578306e-11  7.49021052e-08]]
# [[-5.24685926e-10  6.50628648e-11  2.98152477e-09 -3.96957564e-10
#   -1.82250889e-09 -1.30022455e-07]
#  [ 7.24560796e-10  7.09322179e-12 -4.55769416e-09  2.41843700e-10
#    1.01102464e-09  1.00421890e-07]
#  [-5.60454249e-13  2.54986180e-10  1.68791594e-09 -4.02841837e-11
#   -2.61805996e-10  1.94869091e-08]
#  [ 2.76574305e-10 -1.05239183e-10 -3.68145949e-09  2.95748753e-10
#    1.33578306e-11  7.49021052e-08]]

# %%
np.all(np.isclose(covs_all[:,[7,10,11,13],19:25],covs_all3[:,[7,10,11,13],19:25]))
# Out:
# True
