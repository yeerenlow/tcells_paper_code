# %%
import numpy as np

covs_all = np.load('../data/simulation2/covs_all.npy')
cov = np.load('../data/simulation2/cov_pop.npy')

# %%
num_cells = 10
len_series = np.array([68, 116, 216, 216,  94, 216, 216, 190, 216, 216],dtype=np.int64)

# %%
ns00 = np.zeros((21,21),dtype=np.int64)
ns11 = np.zeros((34,34),dtype=np.int64)
ns22 = np.zeros((11,11),dtype=np.int64)

# %%
list0 = [0,3,4,6,7,9,10,11,12,13,15,18,19,20]
list1 = [2,3,7,8,9,12,14,15,16,17,18,20,24,25,26,28,31,32,33]
list2 = [2,4,5,6,7,8,9,10]

# %%
for i in list0:
    for j in list0:
        if j<=i: continue
        #print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i+4,j+4],[i+4,j+4])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i+4,j+4],[i+4,j+4])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns00[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns00[i,j])
# Out:
# 0 3 23686
# 0 4 96891
# 0 6 1654
# 0 7 14544
# 0 9 1186
# 0 10 10715
# 0 11 1118
# 0 12 1326
# 0 13 2277
# 0 15 1045
# 0 18 1223
# 0 19 87244
# 0 20 2741
# 3 4 18221
# 3 6 3231
# 3 7 49123
# 3 9 1362
# 3 10 10264
# 3 11 1623
# 3 12 1455
# 3 13 92214
# 3 15 6834
# 3 18 4055
# 3 19 778651
# 3 20 20632
# 4 6 0
# 4 7 400392
# 4 9 0
# 4 10 19
# 4 11 0
# 4 12 0
# 4 13 3
# 4 15 0
# 4 18 8
# 4 19 117931
# 4 20 30
# 6 7 119374
# 6 9 31
# 6 10 0
# 6 11 0
# 6 12 391812
# 6 13 895515
# 6 15 351581
# 6 18 0
# 6 19 6043
# 6 20 135
# 7 9 647627
# 7 10 876974
# 7 11 6065
# 7 12 222767
# 7 13 8939
# 7 15 190370
# 7 18 1179636
# 7 19 4299340
# 7 20 360436
# 9 10 0
# 9 11 0
# 9 12 32095
# 9 13 18
# 9 15 0
# 9 18 153
# 9 19 10114
# 9 20 12
# 10 11 0
# 10 12 0
# 10 13 1
# 10 15 0
# 10 18 0
# 10 19 2489077
# 10 20 14277
# 11 12 0
# 11 13 384
# 11 15 0
# 11 18 0
# 11 19 2614
# 11 20 4506
# 12 13 161777
# 12 15 184129
# 12 18 0
# 12 19 4648
# 12 20 17
# 13 15 6896
# 13 18 1
# 13 19 4827
# 13 20 836
# 15 18 0
# 15 19 11727
# 15 20 23
# 18 19 41718
# 18 20 20
# 19 20 965832

# %%
with open('../data/simulation2/ns00.npy','wb') as f:
    np.save(f, ns00)

# %%
ns00 = np.load('../data/simulation2/ns00.npy')

# %%
for i in [0]:
    for j in list0:
        if j<=i: continue
        #print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i+4,j+4],[i+4,j+4])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i+4,j+4],[i+4,j+4])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns00[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns00[i,j])
# Out:
# 0 3 23284
# 0 4 98353
# 0 6 1715
# 0 7 14324
# 0 9 1143
# 0 10 10577
# 0 11 1091
# 0 12 1267
# 0 13 2186
# 0 15 1118
# 0 18 1177
# 0 19 87609
# 0 20 2848

# %%
with open('../data/simulation2/ns00.npy','wb') as f:
    np.save(f, ns00)

# %%
ns00 = np.load('../data/simulation2/ns00.npy')

# %%
for i in list0:
    for j in [3,4,10,11,13]:
        if j<=i: continue
        #print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i+4,j+4],[i+4,j+4])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i+4,j+4],[i+4,j+4])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns00[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns00[i,j])
# Out:
# 0 3 23232
# 0 4 97591
# 0 10 10588
# 0 11 1115
# 0 13 2336
# 3 4 18676
# 3 10 10425
# 3 11 1645
# 3 13 94724
# 4 10 17
# 4 11 0
# 4 13 3
# 6 10 0
# 6 11 0
# 6 13 931369
# 7 10 877135
# 7 11 6071
# 7 13 9108
# 9 10 0
# 9 11 0
# 9 13 16
# 10 11 0
# 10 13 1
# 11 13 398
# 12 13 169718

# %%
for i in [3,4,10,11,13]:
    for j in list0:
        if j<=i: continue
        #print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i+4,j+4],[i+4,j+4])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i+4,j+4],[i+4,j+4])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns00[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns00[i,j])
# Out:
# 3 4 18765
# 3 6 3151
# 3 7 49367
# 3 9 1418
# 3 10 10113
# 3 11 1640
# 3 12 1466
# 3 13 93905
# 3 15 6884
# 3 18 4048
# 3 19 778880
# 3 20 20588
# 4 6 0
# 4 7 400990
# 4 9 0
# 4 10 23
# 4 11 0
# 4 12 0
# 4 13 6
# 4 15 0
# 4 18 2
# 4 19 118480
# 4 20 35
# 10 11 0
# 10 12 0
# 10 13 0
# 10 15 0
# 10 18 0
# 10 19 2491067
# 10 20 14399
# 11 12 0
# 11 13 430
# 11 15 0
# 11 18 0
# 11 19 2567
# 11 20 4508
# 13 15 8311
# 13 18 1
# 13 19 4917
# 13 20 836

# %%
with open('../data/simulation2/ns00.npy','wb') as f:
    np.save(f, ns00)

# %%
for i in list1:
    for j in list1:
        if j<=i: continue
        print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i+25,j+25],[i+25,j+25])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i+25,j+25],[i+25,j+25])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns11[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns11[i,j])
# Out:
# 2 7
# 2 7 242846
# 2 8
# 2 8 57
# 2 9
# 2 9 16971
# 2 12
# 2 12 65128
# 2 14
# 2 14 96731
# 2 15
# 2 15 0
# 2 16
# 2 16 0
# 2 17
# 2 17 0
# 2 18
# 2 18 5691
# 2 20
# 2 20 6933
# 2 24
# 2 24 8
# 2 25
# 2 25 4294
# 2 26
# 2 26 1337
# 2 28
# 2 28 15285
# 2 31
# 2 31 0
# 2 32
# 2 32 1866
# 2 33
# 2 33 0
# 7 8
# 7 8 79057
# 7 9
# 7 9 23732
# 7 12
# 7 12 297567
# 7 14
# 7 14 348694
# 7 15
# 7 15 159012
# 7 16
# 7 16 35174
# 7 17
# 7 17 10683
# 7 18
# 7 18 304245
# 7 20
# 7 20 38021
# 7 24
# 7 24 17432
# 7 25
# 7 25 159176
# 7 26
# 7 26 528413
# 7 28
# 7 28 36865
# 7 31
# 7 31 156370
# 7 32
# 7 32 20626
# 7 33
# 7 33 22628
# 8 9
# 8 9 11837
# 8 12
# 8 12 326707
# 8 14
# 8 14 251461
# 8 15
# 8 15 0
# 8 16
# 8 16 284
# 8 17
# 8 17 147253
# 8 18
# 8 18 108926
# 8 20
# 8 20 541631
# 8 24
# 8 24 15
# 8 25
# 8 25 13894
# 8 26
# 8 26 1307
# 8 28
# 8 28 574115
# 8 31
# 8 31 0
# 8 32
# 8 32 95228
# 8 33
# 8 33 73542
# 9 12
# 9 12 53175
# 9 14
# 9 14 1348619
# 9 15
# 9 15 10569
# 9 16
# 9 16 89802
# 9 17
# 9 17 154091
# 9 18
# 9 18 1591762
# 9 20
# 9 20 1609623
# 9 24
# 9 24 2823
# 9 25
# 9 25 18965
# 9 26
# 9 26 5836
# 9 28
# 9 28 53772
# 9 31
# 9 31 2375
# 9 32
# 9 32 8398
# 9 33
# 9 33 3160
# 12 14
# 12 14 247257
# 12 15
# 12 15 0
# 12 16
# 12 16 0
# 12 17
# 12 17 74
# 12 18
# 12 18 7919
# 12 20
# 12 20 44958
# 12 24
# 12 24 51871
# 12 25
# 12 25 33749
# 12 26
# 12 26 1787
# 12 28
# 12 28 21918
# 12 31
# 12 31 0
# 12 32
# 12 32 30372
# 12 33
# 12 33 4669
# 14 15
# 14 15 3108
# 14 16
# 14 16 20195
# 14 17
# 14 17 31310
# 14 18
# 14 18 4348688
# 14 20
# 14 20 709673
# 14 24
# 14 24 48080
# 14 25
# 14 25 1723847
# 14 26
# 14 26 113294
# 14 28
# 14 28 103369
# 14 31
# 14 31 5295
# 14 32
# 14 32 112747
# 14 33
# 14 33 7972
# 15 16
# 15 16 151468
# 15 17
# 15 17 2251
# 15 18
# 15 18 13432
# 15 20
# 15 20 301921
# 15 24
# 15 24 0
# 15 25
# 15 25 98704
# 15 26
# 15 26 52562
# 15 28
# 15 28 5
# 15 31
# 15 31 492
# 15 32
# 15 32 67696
# 15 33
# 15 33 0
# 16 17
# 16 17 12892
# 16 18
# 16 18 170836
# 16 20
# 16 20 1810606
# 16 24
# 16 24 75
# 16 25
# 16 25 630762
# 16 26
# 16 26 184846
# 16 28
# 16 28 566
# 16 31
# 16 31 7790
# 16 32
# 16 32 95718
# 16 33
# 16 33 17
# 17 18
# 17 18 318393
# 17 20
# 17 20 2653342
# 17 24
# 17 24 9776
# 17 25
# 17 25 473703
# 17 26
# 17 26 22355
# 17 28
# 17 28 55351
# 17 31
# 17 31 546
# 17 32
# 17 32 790281
# 17 33
# 17 33 3392
# 18 20
# 18 20 4449823
# 18 24
# 18 24 6878
# 18 25
# 18 25 1229910
# 18 26
# 18 26 107234
# 18 28
# 18 28 2654
# 18 31
# 18 31 17142
# 18 32
# 18 32 881864
# 18 33
# 18 33 157676
# 20 24
# 20 24 87709
# 20 25
# 20 25 3119767
# 20 26
# 20 26 619068
# 20 28
# 20 28 174228
# 20 31
# 20 31 171430
# 20 32
# 20 32 590094
# 20 33
# 20 33 206157
# 24 25
# 24 25 2178
# 24 26
# 24 26 13288
# 24 28
# 24 28 1437951
# 24 31
# 24 31 7
# 24 32
# 24 32 78134
# 24 33
# 24 33 25374
# 25 26
# 25 26 5411
# 25 28
# 25 28 77063
# 25 31
# 25 31 8312
# 25 32
# 25 32 5731
# 25 33
# 25 33 3397
# 26 28
# 26 28 2320
# 26 31
# 26 31 11022
# 26 32
# 26 32 63748
# 26 33
# 26 33 1764
# 28 31
# 28 31 2
# 28 32
# 28 32 91709
# 28 33
# 28 33 87622
# 31 32
# 31 32 21109
# 31 33
# 31 33 31
# 32 33
# 32 33 3821792

# %%
with open('../data/simulation2/ns11.npy','wb') as f:
    np.save(f, ns11)

# %%
ns11 = np.load('../data/simulation2/ns11.npy')

# %%
for i in [2]:
    for j in [3]:
        if j<=i: continue
        print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i+25,j+25],[i+25,j+25])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i+25,j+25],[i+25,j+25])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns11[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns11[i,j])
# Out:
# 2 3
# 2 3 75

# %%
for i in [3]:
    for j in list1:
        if j<=i: continue
        print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i+25,j+25],[i+25,j+25])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i+25,j+25],[i+25,j+25])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns11[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns11[i,j])
# Out:
# 3 7
# 3 7 1848324
# 3 8
# 3 8 7764
# 3 9
# 3 9 104366
# 3 12
# 3 12 15691
# 3 14
# 3 14 1136599
# 3 15
# 3 15 0
# 3 16
# 3 16 0
# 3 17
# 3 17 0
# 3 18
# 3 18 20887
# 3 20
# 3 20 54813
# 3 24
# 3 24 8
# 3 25
# 3 25 15916
# 3 26
# 3 26 1642
# 3 28
# 3 28 1791
# 3 31
# 3 31 0
# 3 32
# 3 32 999
# 3 33
# 3 33 0

# %%
with open('../data/simulation2/ns11.npy','wb') as f:
    np.save(f, ns11)

# %%
for i in list2:
    for j in list2:
        if j<=i: continue
        print(i,j)
        eigvals = np.zeros((num_cells,2))
        sqrt_eigvals = np.zeros((num_cells,2))
        eigvecs = np.zeros((num_cells,2,2))
        for c in range(num_cells):
            #mat = np.array([[S00[c],covs[c,0,1],covs[c,0,2],covs[c,0,6]],[covs[c,1,0],covs[c,1,1],covs[c,1,2],covs[c,1,6]],[covs[c,2,0],covs[c,2,1],covs[c,2,2],covs[c,2,6]],[covs[c,6,0],covs[c,6,1],covs[c,6,2],covs[c,6,6]]])
            #eigvals[c], eigvecs[c] = np.linalg.eigh(mat)
            eigvals[c], eigvecs[c] = np.linalg.eigh(covs_all[np.ix_([c],[i+59,j+59],[i+59,j+59])])
            sqrt_eigvals[c] = np.sqrt(eigvals[c])

        num_trials = 5000000
        vals = np.zeros((num_trials,num_cells,2))
        for tr in range(num_trials):
            #if tr%10000==0: print(tr)
            for c in range(num_cells):
                vals[tr,c] = eigvecs[c]@(sqrt_eigvals[c]*np.random.normal(size=(2,)))
        
        means_sim = np.zeros((num_trials,2))
        means_sim = np.sum(vals*len_series[np.newaxis,:,np.newaxis], axis=1)/np.sum(len_series[:])
        
        covs_sim = np.zeros((num_trials,2,2))
        for k in range(2):
            for l in range(2):
                covs_sim[:,k,l] = np.sum(len_series[np.newaxis,:]*(vals[:,:,k]-means_sim[:,np.newaxis,k])*(vals[:,:,l]-means_sim[:,np.newaxis,l]), axis=1)/np.sum(len_series[:])
        covs_diff = cov[np.ix_([i+59,j+59],[i+59,j+59])][np.newaxis,:,:] - covs_sim
        
        #scale_mat_inv = np.linalg.inv(scale_mat[np.ix_([i,j],[i,j])])
        #mat_sim = np.matmul(covs_diff, scale_mat_inv)
        a = covs_diff[:,0,0]
        b = covs_diff[:,0,1]
        c = covs_diff[:,1,0]
        d = covs_diff[:,1,1]
        eigs_sim = (a+d-np.sqrt((a-d)**2+4*b*c))/2
        ns22[i,j] = np.sum(np.where(eigs_sim<=0,1,0))
        print(i,j,ns22[i,j])
# Out:
# 2 4
# 2 4 16
# 2 5
# 2 5 132482
# 2 6
# 2 6 1615
# 2 7
# 2 7 22456
# 2 8
# 2 8 8
# 2 9
# 2 9 19208
# 2 10
# 2 10 660
# 4 5
# 4 5 29
# 4 6
# 4 6 2788
# 4 7
# 4 7 162643
# 4 8
# 4 8 208811
# 4 9
# 4 9 1
# 4 10
# 4 10 7240
# 5 6
# 5 6 1674380
# 5 7
# 5 7 155660
# 5 8
# 5 8 93
# 5 9
# 5 9 3976231
# 5 10
# 5 10 1707899
# 6 7
# 6 7 178474
# 6 8
# 6 8 67
# 6 9
# 6 9 766981
# 6 10
# 6 10 2391573
# 7 8
# 7 8 106446
# 7 9
# 7 9 96078
# 7 10
# 7 10 31502
# 8 9
# 8 9 0
# 8 10
# 8 10 3
# 9 10
# 9 10 59618

# %%
with open('../data/simulation2/ns22.npy','wb') as f:
    np.save(f, ns22)
